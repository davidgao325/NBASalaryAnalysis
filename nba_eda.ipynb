# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('cleanedup_data.csv')
df.drop(["Unnamed: 0"], axis=1, inplace=True)
df.head()
# Out:
#               Player  CurrentSalary  UpcomingSalary  Age   Tm   G    MP   3PA  \
# 0      Stephen Curry       40231758        43006362   31  GSW   5  27.8   9.8
# 1         Chris Paul       38506482        41358814   34  OKC  63  31.8   4.4
# 2  Russell Westbrook       38178000        41006000   31  HOU  53  35.9   3.8
# 3       James Harden       37800000        40824000   30  HOU  61  36.7  12.6
# 4       LeBron James       37436858        39219565   35  LAL  60  34.9   6.4
#
#      3P%  TRB  ...   PTS   PER    TS%  OWS  DWS    WS  OBPM  DBPM  BPM  VORP
# 0  0.245  5.2  ...  20.8  21.7  0.557  0.2  0.1   0.3   4.5  -0.6  3.9   0.2
# 1  0.362  4.9  ...  17.7  21.7  0.609  5.5  2.5   8.1   3.1   1.2  4.3   3.2
# 2  0.254  8.0  ...  27.5  21.5  0.539  2.1  2.3   4.3   1.9  -0.1  1.8   1.8
# 3  0.352  6.4  ...  34.4  28.4  0.616  8.7  2.7  11.5   7.9   1.2  9.0   6.3
# 4  0.349  7.9  ...  25.7  26.0  0.582  6.1  3.4   9.5   6.8   1.9  8.7   5.7
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#              Player  CurrentSalary  UpcomingSalary  Age   Tm  G   MP  3PA  \
# 442    Zach Norvell          50752               0   22  TOT  5  8.2  1.6
# 443    Malik Newman          50752               0   22  CLE  1  4.0  1.0
# 444  Marques Bolden          50752               0   21  CLE  1  3.0  0.0
# 445     Paul Watson          50752               0   25  TOT  5  5.0  0.8
# 446  William Howard          50000               0   26  HOU  2  6.5  2.0
#
#        3P%  TRB  ...  PTS   PER    TS%  OWS  DWS   WS  OBPM  DBPM   BPM  VORP
# 442  0.375  1.2  ...  2.0   2.6  0.402 -0.1  0.0 -0.1  -7.1  -1.2  -8.3  -0.1
# 443  0.000  0.0  ...  2.0 -11.3  0.347  0.0  0.0  0.0 -14.5 -11.3 -25.9   0.0
# 444  0.000  2.0  ...  0.0  19.8  0.000  0.0  0.0  0.0  -5.8  11.3   5.5   0.0
# 445  0.000  0.8  ...  0.2  -0.5  0.056 -0.1  0.0 -0.1  -8.0   0.8  -7.3   0.0
# 446  0.000  1.0  ...  0.0 -12.7  0.000 -0.1  0.0 -0.1 -14.9  -5.7 -20.7  -0.1
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#        CurrentSalary  UpcomingSalary         Age           G          MP  \
# count   4.470000e+02    4.470000e+02  447.000000  447.000000  447.000000
# mean    7.675392e+06    6.669605e+06   25.854586   42.906040   20.601790
# std     8.917934e+06    9.541633e+06    4.143596   18.969178    9.150464
# min     5.000000e+04    0.000000e+00   19.000000    1.000000    1.000000
# 25%     1.678854e+06    0.000000e+00   23.000000   29.000000   13.300000
# 50%     3.500000e+06    2.286357e+06   25.000000   49.000000   20.300000
# 75%     1.018798e+07    8.621873e+06   29.000000   58.000000   28.600000
# max     4.023176e+07    4.300636e+07   43.000000   66.000000   36.900000
#
#               3PA         3P%         TRB         BLK        STL  ...  \
# count  447.000000  447.000000  447.000000  447.000000  447.00000  ...
# mean     2.867114    0.297020    3.841163    0.422819    0.64877  ...
# std      2.300949    0.139755    2.526435    0.424864    0.40611  ...
# ...

# %%
df.columns
# Out:
# Index(['Player', 'CurrentSalary', 'UpcomingSalary', 'Age', 'Tm', 'G', 'MP',
#        '3PA', '3P%', 'TRB', 'BLK', 'STL', 'AST', 'TOV', 'PTS', 'PER', 'TS%',
#        'OWS', 'DWS', 'WS', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Player            447
# CurrentSalary     320
# UpcomingSalary    220
# Age                22
# Tm                 31
# G                  65
# MP                246
# 3PA                89
# 3P%               180
# TRB               100
# BLK                24
# STL                22
# AST                74
# TOV                42
# PTS               199
# PER               188
# TS%               223
# OWS                64
# DWS                41
# WS                 85
# OBPM              130
# DBPM               75
# BPM               138
# VORP               52
# dtype: int64

# %%
df.Age.hist()

# %%
df.G.hist()

# %%
df.WS.hist()

# %%
df.boxplot(column = 'WS')

# %%
df.boxplot(column = 'PTS')

# %%
df[['MP', 'CurrentSalary']].corr()
# Out:
#                      MP  CurrentSalary
# MP             1.000000       0.578988
# CurrentSalary  0.578988       1.000000

# %%
df[['TOV', 'CurrentSalary']].corr()
# Out:
#                     TOV  CurrentSalary
# TOV            1.000000       0.602458
# CurrentSalary  0.602458       1.000000

# %%
df[['STL', 'CurrentSalary']].corr()
# Out:
#                     STL  CurrentSalary
# STL            1.000000       0.448044
# CurrentSalary  0.448044       1.000000

# %%
df[['BLK', 'CurrentSalary']].corr()
# Out:
#                     BLK  CurrentSalary
# BLK            1.000000       0.299248
# CurrentSalary  0.299248       1.000000

# %%
df[['BPM', 'CurrentSalary']].corr()
# Out:
#                     BPM  CurrentSalary
# BPM            1.000000       0.444958
# CurrentSalary  0.444958       1.000000

# %%
df[['VORP', 'CurrentSalary']].corr()
# Out:
#                    VORP  CurrentSalary
# VORP           1.000000       0.578379
# CurrentSalary  0.578379       1.000000

# %%
df[['TS%', 'CurrentSalary']].corr()
# Out:
#                     TS%  CurrentSalary
# TS%            1.000000       0.182686
# CurrentSalary  0.182686       1.000000

# %%
df[['CurrentSalary', 'AST']].corr()
# Out:
#                CurrentSalary       AST
# CurrentSalary       1.000000  0.555822
# AST                 0.555822  1.000000

# %%
df[['G', 'CurrentSalary']].corr()
# Out:
#                       G  CurrentSalary
# G              1.000000       0.244489
# CurrentSalary  0.244489       1.000000

# %%
df[['Age','CurrentSalary']].corr()
# Out:
#                     Age  CurrentSalary
# Age            1.000000       0.396987
# CurrentSalary  0.396987       1.000000

# %%
df[['PTS', 'CurrentSalary']].corr()
# Out:
#                     PTS  CurrentSalary
# PTS            1.000000       0.644059
# CurrentSalary  0.644059       1.000000

# %%
df[['TRB', 'CurrentSalary']].corr()
# Out:
#                     TRB  CurrentSalary
# TRB            1.000000       0.502645
# CurrentSalary  0.502645       1.000000

# %%
df[['CurrentSalary', 'PER']].corr(method='pearson')
# Out:
#                CurrentSalary       PER
# CurrentSalary       1.000000  0.449718
# PER                 0.449718  1.000000

# %%
df[['CurrentSalary', 'WS']].corr()
# Out:
#                CurrentSalary        WS
# CurrentSalary       1.000000  0.545909
# WS                  0.545909  1.000000

# %%
df[['OWS', 'CurrentSalary']].corr()
# Out:
#                     OWS  CurrentSalary
# OWS            1.000000       0.523121
# CurrentSalary  0.523121       1.000000

# %%
df[['DWS', 'CurrentSalary']].corr()
# Out:
#                     DWS  CurrentSalary
# DWS            1.000000       0.455959
# CurrentSalary  0.455959       1.000000

# %%
df[['OBPM', 'CurrentSalary']].corr()
# Out:
#                    OBPM  CurrentSalary
# OBPM           1.000000       0.488328
# CurrentSalary  0.488328       1.000000

# %%
df[['DBPM', 'CurrentSalary']].corr()
# Out:
#                    DBPM  CurrentSalary
# DBPM           1.000000       0.088629
# CurrentSalary  0.088629       1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['Age', 'CurrentSalary','G']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.pairplot(df)

# %%
sns.relplot(x= 'G', y=' CurrentSalary',  data=df )

# %%
sns.distplot(df['WS'])

# %%
sns.relplot(x= 'G', y='WS',  data=df)

# %%
sns.relplot(x= 'AST', y='PTS',  data=df)

# %%
sns.relplot(x= 'G', y=' CurrentSalary',  data=df)

# %%
sns.relplot(x= 'TRB', y='PTS',  data=df )

# %%
sns.relplot(x= 'PTS', y='WS',  data=df)

# %%
sns.relplot(x= 'TRB', y='WS',  data=df)

# %%
df.to_csv('nba_eda.csv')
